# %%
def example(a):
    ''' 
        this is documentation.
        this is second line.    
    '''
    return a * a

#print (example(2))
print (example.__doc__)
# Out:
#
#         this is documentation.
#         this is second line.

# %%
z = ''' This is a variable. 
        this is second line.
    '''
print('''This string has a single (') and a double (") quote.''')
print (z)
# Out:
#  This is a variable.
#         this is second line.

# %%
# 0o - octal
print(0o10 + 12)
# Out:
# 20

# %%
# 0o - hexadecimal
print(0x10)
# Out:
# 16

# %%
# 0o - binary
print(0b1011)
# Out:
# 11

# %%
5e-324
print (10**2)
# Out:
# 100

# %%
print (1e-325)
print (100 / 3)
print (33.3333333333336 * 3)
# Out:
# 0.0
# 33.333333333333336
# 100.0000000000008

# %%
1.8e308
# Out:
# inf

# %%
5e-325
# Out:
# 0.0

# %%
a = 1e-325
type(a)
# Out:
# float

# %%
a = -9+2j
type(a)
# Out:
# complex

# %%
print('a\
b\
c')
# Out:
# abc

# %%
pow(2,2)
# Out:
# 4

# %%
x = 5
y = x + 'hello'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-e8bba2d33eed> in <module>()
#       1 x = 5
# ----> 2 y = x + 'hello'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print ('hello" \'this is somthien')
# Out:
# hello" 'this is somthien

# %%
def func(name):
    print ("hello, ",name)
func("Hemant")
# Out:
# hello,  Hemant

# %%
print ('''
this ''
""
that
''')
# Out:
# this ''
# ""
# that

# %%
print (xb01237dkjs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-998d70f581e6> in <module>()
# ----> 1 print (xb01237dkjs)
#
# NameError: name 'xb01237dkjs' is not defined

# %%
a = None

# %%
print (a)
# Out:
# None

# %%
b
print (b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-f5853ae39350> in <module>()
# ----> 1 b
#       2 print (b)
#
# NameError: name 'b' is not defined

# %%
thislist = ["apple", "banana", "cherry"]
print(len(thislist))
print (thislist[-1:0])
for item in reversed(thislist):
    print (item)
    
print (reversed())
# Out:
# 3
# []
# cherry
# banana
# apple
# <list_reverseiterator object at 0x000001FDD0E0B550>

# %%
thislist = ["apple", "banana", "cherry"]
mainlist = [thislist, "sugar"]
# print(len(thislist))
# print (thislist[0:-1])
print (mainlist)
# Out:
# [['apple', 'banana', 'cherry'], 'sugar']

# %%
#thislist
thislist.reverse()
print (thislist)
# Out:
# ['cherry', 'banana', 'apple']

# %%
print (a)
# Out:
# None

# %%
thisset = {"apple", "banana", "cherry"}

for x in thisset:
  print(x)
# Out:
# banana
# apple
# cherry

# %%
for x in thisset:
  print(x)
# Out:
# banana
# apple
# cherry

# %%
for x in thisset:
  print(x)
# Out:
# banana
# apple
# cherry

# %%
print (thisset)
# Out:
# {'banana', 'apple', 'cherry'}

# %%
"banana" in thisset
# Out:
# True

# %%
thislist
# Out:
# ['cherry', 'banana', 'apple']

# %%
for x, y in thislist:
    print (x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-38c3664c79d0> in <module>()
# ----> 1 for x, y in thislist:
#       2     print (x,y)
#
# ValueError: too many values to unpack (expected 2)

# %%
type(thislist)
# Out:
# list

# %%
type(thisset)
# Out:
# set

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4, 5])
plt.show()

# %%
a = range(1,200)

# %%
print (a)
# Out:
# range(1, 200)
