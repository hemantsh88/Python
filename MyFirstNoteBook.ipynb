# %%
print ("hello world")
# Out:
# hello world

# %%
def print_something(name):
    print ("hello {0}".format(name))

# %%
print_something("hemant")
# Out:
# hello hemant

# %%
! python

# %%
import matplotlib.pyplot as plt
plt.plot([11,22,44,67,2,39])
plt.show()
